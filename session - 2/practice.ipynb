# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
im=Image.open("thor.jpg")
arr = np.array(im)

# %%
plt.imshow(arr)

# %%
work = arr.copy()
plt.imshow(work)

# %%
work[:,:,[1,2]]=0
plt.imshow(work)

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'
